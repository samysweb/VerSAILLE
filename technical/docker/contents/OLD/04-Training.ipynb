# %% [markdown]
# # Training a Neural Network for Adaptive Cruise Control
#
# Now that we have proven the correctness of an abstract system and derived a specification for the neural network, it is time to train such a neural network.

# %% [markdown]
# ## Intro
# This notebook trains a neural network for adaptive cruise control in a highly simplified setting.
#
# ![grafik.png](attachment:b10a6c91-db7b-4136-845a-a755cdbc7f00.png)
#
# - The system is described by two variables: Relative (!) Position $p_{\text{rel}}$ and Velocity $v_{\text{rel}}$
# - The Neural Network determines the acceleration of the car in the back via discrete control:
#   Accelerate ($a_{\text{rel}}=-A$); No Acceleration ($a_{\text{rel}}=0$); Brake ($a_{\text{rel}}=B$)
# - The dynamics of the system are given as $p_{\text{rel}}'=v_{\text{rel}},v_{\text{rel}}'=a_{\text{rel}}$ and there is a control decision at least every $0.1$ seconds
# - To keep the system safe, we must ensure that the car in the back never crashes into the car in the front

# %% [markdown]
# ## Setup

# %%
import libs.acc
from libs.gym_helper import *
import gymnasium as gym
from gymnasium import wrappers

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
import time
import numpy as np

set_random_seed(0)

# %%
# Initialize Evaluation Environment for ACC
eval_env = Monitor(gym.make('acc-discrete-v0'))

# %% [markdown]
# Next, we initialize the environment.
# To see, how we can implement environments, feel free to have a look at `./libs/acc.py`
#
# #### Digression: Reward Function
# We will train our agent via Reinforcement Learning.
# To this end, we require a reward function which tells our agent whether its behavior is good or not.
#
# The computation of the reward is implemented in the `step` function of the environment in `./libs/acc.py`
#
# Unfortunately, designing good loss functions is a very complicated topic where [lots of things can go wrong](https://par.nsf.gov/servlets/purl/10424463).
# Fortunately, in our case the reward function fell from the sky:
# - If the agent is still alive and well: +0.1
# - If the agent crashed: -200
# - If the agent's position is larger than the cutoff ($>100$): -50

# %% [markdown]
# ## Training a bad model
# To see that our NN verification actually works as inteded, we begin by training a decidedly **bad** model.
# To this end, we invert the reward function, i.e. our model is rewarded for crashing and falling behind...

# %%
# Initialize Environment and Train Model
env1 = get_env1()
model1 = train_model1(env1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Performing some training steps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62       |
# |    ep_rew_mean     | 93.9     |
# | time/              |          |
# |    fps             | 2645     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.8        |
# |    ep_rew_mean          | 89          |
# | time/                   |             |
# |    fps                  | 1952        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008028005 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.088      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 576         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 1.8e+03     |
# -----------------------------------------
# Model saved in bad_nn.onnx

# %% [markdown]
# ### Let's see how bad it is...

# %%
show_run(eval_env, model1.predict, obs=[50,-8])
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# ## Training a good model
# OK, I guess we have learned our lesson...

# %%
# Initialize Training Environment for ACC
env = gym.make("acc-discrete-v0")
# Bad idea:
# env.unwrapped.invert_loss=True

# %%
# Initialize Agent
architecture = dict(pi=[64, 64, 64, 64], vf=[64, 64, 64, 64])
good_model = PPO("MlpPolicy", env, verbose=1,policy_kwargs={"activation_fn":nn.ReLU,"net_arch":architecture})
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### Evaluation
# Now that we have an agent, we can test the agent and see what reward we currently get.
# To this end, we setup a new evaluation environment and use the function `evaluate_policy`:

# %%
# Evaluate untrained agent
mean_reward, std_reward = evaluate_policy(good_model, eval_env, n_eval_episodes=1000, deterministic=True)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-112.03 +/- 83.16

# %% [markdown]
# We can also have a look at what the behavior of the agent looks like:

# %%
show_run(eval_env, good_model.predict)
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# Just in case, we save a copy of the untrained neural network...

# %% [markdown]
# ### Training
# To get a better agent, we must train the model.
# This takes 5-10 minutes

# %%
# Train agent
good_model.learn(total_timesteps=200_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.2     |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    fps             | 2298     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.2         |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 1563         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0071009817 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0449       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 492          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.5         |
# |    ep_rew_mean          | -104         |
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0050119213 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.3         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 152          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -95.7       |
# | time/                   |             |
# |    fps                  | 1274        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009229125 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 65          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -85.9       |
# | time/                   |             |
# |    fps                  | 1207        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.030730305 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -81.2       |
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018274996 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 29.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | -71.7       |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.021001011 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.43        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 90.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | -62.9        |
# | time/                   |              |
# |    fps                  | 1121         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060622273 |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.171        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000538    |
# |    value_loss           | 2.97         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | -54.3       |
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011040143 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -1.28       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0942      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.000774    |
# |    value_loss           | 0.437       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 189          |
# |    ep_rew_mean          | -48.7        |
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0009545408 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.356        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.39         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000236     |
# |    value_loss           | 13           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | -41.5       |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 11          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005668477 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0033     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.000417    |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 223         |
# |    ep_rew_mean          | -32.8       |
# | time/                   |             |
# |    fps                  | 1056        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005488511 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0421      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000492   |
# |    value_loss           | 2.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | -25.5        |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 13           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0072418572 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.988       |
# |    explained_variance   | -0.339       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0297      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 257          |
# |    ep_rew_mean          | -15.4        |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 14           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0046395254 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.246       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0232      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.00168      |
# |    value_loss           | 0.0496       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | -13.3        |
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 15           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0027370001 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.076        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000908     |
# |    value_loss           | 0.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | -5.94        |
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 16           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0035564592 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.1         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | 2.69        |
# | time/                   |             |
# |    fps                  | 1056        |
# |    iterations           | 17          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008940561 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -1.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 0.0692      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 8.19         |
# | time/                   |              |
# |    fps                  | 1050         |
# |    iterations           | 18           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0014260598 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.0298       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.83         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000743    |
# |    value_loss           | 5.24         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 325        |
# |    ep_rew_mean          | 12.4       |
# | time/                   |            |
# |    fps                  | 1053       |
# |    iterations           | 19         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01342829 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.942     |
# |    explained_variance   | 0.76       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.246      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.000574  |
# |    value_loss           | 10.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 20          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006071101 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | -0.364      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00827    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 0.0848      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 347          |
# |    ep_rew_mean          | 19.7         |
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 21           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0066926135 |
# |    clip_fraction        | 0.0991       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.489        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000535     |
# |    value_loss           | 4.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 357          |
# |    ep_rew_mean          | 22.2         |
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 22           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0071195657 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.952       |
# |    explained_variance   | -2.28        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000649    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00056     |
# |    value_loss           | 0.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | 24.7        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 23          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011399282 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -2.99       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.089       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 373         |
# |    ep_rew_mean          | 27.3        |
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 24          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014735842 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.372      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 0.0653      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 25          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004683136 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | -0.0224     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.01        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 26          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021042021 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.815       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 27          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013655532 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000557   |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00187     |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 29.8        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 28          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013095315 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | -0.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 0.201       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 383        |
# |    ep_rew_mean          | 29.8       |
# | time/                   |            |
# |    fps                  | 1050       |
# |    iterations           | 29         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01292616 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | -0.298     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0312    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.000688  |
# |    value_loss           | 5.96       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | 29.8         |
# | time/                   |              |
# |    fps                  | 1048         |
# |    iterations           | 30           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0119082555 |
# |    clip_fraction        | 0.176        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.371        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00157      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0093      |
# |    value_loss           | 0.0697       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | 29.8         |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 31           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0017465634 |
# |    clip_fraction        | 0.00381      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.0819       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.422        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 9.83         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 383        |
# |    ep_rew_mean          | 29.8       |
# | time/                   |            |
# |    fps                  | 1048       |
# |    iterations           | 32         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00866822 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.995     |
# |    explained_variance   | -15        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0473     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00257   |
# |    value_loss           | 0.282      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 29.8        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 33          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007796986 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | -0.867      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00547     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00215     |
# |    value_loss           | 0.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 34          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009598986 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -2.71       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0302      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 0.21        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | 31.3         |
# | time/                   |              |
# |    fps                  | 1047         |
# |    iterations           | 35           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0020915873 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.0917       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0896       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 7.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | 31.3         |
# | time/                   |              |
# |    fps                  | 1048         |
# |    iterations           | 36           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0055190744 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.963       |
# |    explained_variance   | 0.26         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.098        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00276      |
# |    value_loss           | 0.143        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 387          |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 37           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0047633015 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.438        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.231        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 4.43         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 38          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020864822 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0902      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 0.147       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 387          |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 1047         |
# |    iterations           | 39           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0029359008 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | -0.287       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0122      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.0147       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 40          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012710042 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | -2.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0066      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 0.0386      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 41          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.022879642 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | -1.77       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000849   |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 0.0465      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | 33.7        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 42          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011658997 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0.0496      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0135      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 0.027       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 392          |
# |    ep_rew_mean          | 35.2         |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 43           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0066489745 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0234       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 0.0597       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 44          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011221407 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | -2.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0129      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.000119    |
# |    value_loss           | 0.024       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 45          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007824158 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | -0.00551    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 46          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030747684 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 396        |
# |    ep_rew_mean          | 37.6       |
# | time/                   |            |
# |    fps                  | 1044       |
# |    iterations           | 47         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.02152753 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.821     |
# |    explained_variance   | 0.525      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0335    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0206    |
# |    value_loss           | 0.0147     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 48          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016173186 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0216      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 0.0229      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 49          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.020486815 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00427    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00823    |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 38.5         |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 50           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0061050635 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | -0.156       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0118      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 0.0194       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 51          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.011272145 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0255      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00248     |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 52          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010359832 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00653    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | 39.4         |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 53           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0068119876 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00346     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00633      |
# |    value_loss           | 0.0243       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | 39.4        |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 54          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.009029639 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00224     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 0.00874     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | 39.4         |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 55           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0040576095 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 391         |
# |    ep_rew_mean          | 29.1        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 81          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.006978221 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00492     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.00174     |
# |    value_loss           | 0.00448     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 395         |
# |    ep_rew_mean          | 31.5        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 82          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.009025247 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0412      |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 0.0158      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 399         |
# |    ep_rew_mean          | 33.9        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 83          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.007988928 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.0017      |
# |    value_loss           | 0.00466     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | 36.3        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 84          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.008014366 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 0.00653     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | 36.3        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 85          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.006720255 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00909    |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 0.0138      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 86          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.009729091 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | -0.244      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0282     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.00423     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 87          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.012875939 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00472    |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.000981   |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 88          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.012379674 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00765     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00584     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 89          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.013922533 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.00598     |
# |    value_loss           | 0.00792     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | 41           |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 90           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0045742663 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0199       |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 5.91e-05     |
# |    value_loss           | 0.0144       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | 41           |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 91           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0074119805 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00714     |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 92          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010447135 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00416    |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.00129     |
# |    value_loss           | 0.00808     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | 38.6         |
# | time/                   |              |
# |    fps                  | 1043         |
# |    iterations           | 93           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0063652694 |
# |    clip_fraction        | 0.0994       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00304      |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00554     |
# |    value_loss           | 0.0162       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 94          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.011246828 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -8.05e-05   |
# |    value_loss           | 9.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 95          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.022566669 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | -0.232      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.052       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 0.027       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 96          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010089049 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00719     |
# |    value_loss           | 0.0138      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | 38.6         |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 97           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0068190936 |
# |    clip_fraction        | 0.0839       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -2.23        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0121       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.00119      |
# |    value_loss           | 0.0307       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 98          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.004624852 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00868     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.00126     |
# |    value_loss           | 0.0121      |
# -----------------------------------------

# %% [markdown]
# Now we can evaluate again...

# %%
# Evaluate untrained agent
mean_reward, std_reward = evaluate_policy(good_model, eval_env, n_eval_episodes=1000, deterministic=True)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Evaluate untrained agent
# ----> 2 mean_reward, std_reward = evaluate_policy(good_model, eval_env, n_eval_episodes=1000, deterministic=True)
#       3 print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:88, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      86 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      87 while (episode_counts < episode_count_targets).any():
# ---> 88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
#      94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/stable_baselines3/common/policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/stable_baselines3/common/policies.py:717, in ActorCriticPolicy._predict(self, observation, deterministic)
#     709 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     710     """
#     711     Get the action according to the policy for a given observation.
#     712
#    (...)
#     715     :return: Taken action according to the policy
#     716     """
# --> 717     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/stable_baselines3/common/policies.py:751, in ActorCriticPolicy.get_distribution(self, obs)
#     744 """
#     745 Get the current policy distribution given the observations.
#     746
#     747 :param obs:
#     748 :return: the action distribution.
#     749 """
#     750 features = super().extract_features(obs, self.pi_features_extractor)
# --> 751 latent_pi = self.mlp_extractor.forward_actor(features)
#     752 return self._get_action_dist_from_latent(latent_pi)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/stable_baselines3/common/torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/modules/activation.py:104, in ReLU.forward(self, input)
#     103 def forward(self, input: Tensor) -> Tensor:
# --> 104     return F.relu(input, inplace=self.inplace)
#
# File /opt/conda/envs/versaille/lib/python3.8/site-packages/torch/nn/functional.py:1500, in relu(input, inplace)
#    1498     result = torch.relu_(input)
#    1499 else:
# -> 1500     result = torch.relu(input)
#    1501 return result
#
# KeyboardInterrupt:

# %% [markdown]
# ...and look at what the policy does...

# %%
show_run(eval_env, good_model.predict, obs=[50,-8])
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# Now we save the policy neural network to use it later...

# %%
extract_onnx(good_model,"good_nn.onnx")
# Out:
# Model saved in good_nn.onnx
